# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("C:\\Users\\AKASH SONI\\Downloads\\housePricing.csv")
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
labelencoder= LabelEncoder()

data["street"]=labelencoder.fit_transform(data["street"])

data["statezip"]=labelencoder.fit_transform(data["statezip"])


data["city"]=labelencoder.fit_transform(data["city"])


data["country"]=labelencoder.fit_transform(data["country"])

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated  street  city  statezip  country
# 0          2005    1522    36        62        0
# 1             0    3899    35        58        0
# 2             0    2291    18        26        0
# 3             0    4263     3         7        0
# 4          1992    4352    31        31        0

# %%
data=data.drop(['date'],axis=1)

# %%
data.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  street  \
# 0     0          3        1340              0      1955          2005    1522
# 1     4          5        3370            280      1921             0    3899
# 2     0          4        1930              0      1966             0    2291
# 3     0          4        1000           1000      1963             0    4263
# 4     0          4        1140            800      1976          1992    4352
#
#    city  statezip  country
# 0    36        62        0
# 1    35        58        0
# 2    18        26        0
# 3     3         7        0
# 4    31        31        0

# %%
x =data.drop(['price'],axis=1) 
y = data['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =  train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train= pd.DataFrame(data = scaler.transform(x_train),columns = x_train.columns,index = x_train.index)

# %%
x_train.head()
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 2195  0.333333   0.222222     0.099245  0.000564     0.8         0.0   0.0
# 631   0.333333   0.148148     0.143474  0.003464     0.2         0.0   0.0
# 3670  0.333333   0.370370     0.240561  0.003563     0.4         0.0   0.0
# 1958  0.333333   0.296296     0.141316  0.007213     0.0         0.0   0.0
# 3284  0.444444   0.481481     0.418554  0.007349     0.4         0.0   0.0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated    street  \
# 2195       0.50    0.120261            0.0  0.877193      0.000000  0.730693
# 631        0.75    0.173856            0.0  0.052632      0.988083  0.053773
# 3670       0.50    0.291503            0.0  0.903509      0.000000  0.210224
# 1958       0.50    0.171242            0.0  0.815789      0.000000  0.863244
# 3284       0.50    0.507190            0.0  0.912281      0.994538  0.770303
#
#           city  statezip  country
# 2195  0.813953  0.618421      0.0
# 631   0.813953  0.776316      0.0
# 3670  0.395349  0.210526      0.0
# 1958  0.279070  0.157895      0.0
# 3284  0.069767  0.039474      0.0

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country'],
#       dtype='object')

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
