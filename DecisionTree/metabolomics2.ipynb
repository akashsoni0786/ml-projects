# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\AKASH SONI\\Desktop\\akashDATACancer.csv")
# C:\Users\AKASH SONI\Desktop\FILES

# data['Class']=data.dropna(subset=['Class'])
data1= data.replace("NaN",np.nan)
data2= data1.fillna(0)
#  data2['Class'] = data2.dropna(subset=['Class'])
# data['Class'].isnull().sum()
# data2.isnull().sum()
# data2[['Class']]
data
# Out:
#      Idx    SampleID SampleType Class     M1       M2     M3    M4     M5  \
# 0      1    sample_1         QC    QC   90.1    491.6  202.9  35.0  164.2
# 1      2    sample_2     Sample    GC   43.0    525.7  130.2   NaN  694.5
# 2      3    sample_3     Sample    BN  214.3  10703.2  104.7  46.8  483.4
# 3      4    sample_4     Sample    HE   31.6     59.7   86.4  14.0   88.6
# 4      5    sample_5     Sample    GC   81.9    258.7  315.1   8.7  243.2
# ..   ...         ...        ...   ...    ...      ...    ...   ...    ...
# 135  136  sample_136         QC    QC   97.6    341.1  232.1  38.1  174.0
# 136  137  sample_137     Sample    GC  405.3    510.7  521.9  91.9  732.1
# 137  138  sample_138     Sample    BN   45.4    191.6   41.0  18.7   40.8
# 138  139  sample_139     Sample    HE   30.7     56.8   35.9  20.9   17.4
# 139  140  sample_140         QC    QC   99.8    342.7  247.4  28.0  166.6
#
#         M6  ...   M140    M141   M142    M143   M144   M145   M146   M147  \
# ...

# %%
def healthFunc(k):
    if k == "QC":
        return 0
    if k == "GC":
        return 1
    if k == "BN":
        return 2 
    if k == "HE":
        return 3

    
data2[['Class']]=data2['Class'].apply(healthFunc)
x=data2.iloc[:,4:].values
y=data2[['Class']]

# for i in enumerate(y):
#     y[i]=y.astype('int')
# # y=y.astype('int').values
# y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y)

print(x_train.size)
print(y_train.size)

print(x_test.size)
print(y_test.size)
# Out:
# 15645
# 105
# 5215
# 35

# %%
from sklearn import tree
t= tree.DecisionTreeClassifier()
t.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
t.predict(x_test)
# Out:
# array([1, 1, 3, 2, 2, 2, 1, 2, 3, 3, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 0, 1,
#        0, 0, 0, 2, 0, 3, 3, 3, 2, 3, 1, 2, 0], dtype=int64)
